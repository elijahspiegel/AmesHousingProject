# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import export_graphviz
from sklearn import preprocessing

# %%
df_raw = pd.read_csv('./data/Ames_HousePrice_processed.csv', index_col=0)
print(df_raw.shape)
df_raw.columns
# Out:
# (2579, 90)
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'ExteriorSF',
#        'AgeAtSale', 'TotalFullBath', 'TotalHalfBath', 'GarageAgeAtSale',
#        'Prop_Addr', 'MA_Ownr1', 'MA_Ownr2', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_raw
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          0.0
# 1     905476230       1049     139500         120       RL         42.0
# 2     911128020       1001     124900          30  C (all)         60.0
# 3     535377150       1039     114000          70       RL         80.0
# 4     534177230       1665     227000          60       RL         70.0
# ...         ...        ...        ...         ...      ...          ...
# 2574  903205040        952     121000          30       RL          0.0
# 2575  905402060       1733     139600          20       RL          0.0
# 2576  909275030       2002     145000          90       RH         82.0
# 2577  907192040       1842     217500          60       RL          0.0
# 2578  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street     Alley LotShape  ... ExteriorSF AgeAtSale  \
# 0        7890   Pave  No alley      Reg  ...       7034        71
# 1        4235   Pave  No alley      Reg  ...       3186        25
# 2        6060   Pave  No alley      Reg  ...       5059        77
# 3        8146   Pave  No alley      Reg  ...       7429       109
# 4        8400   Pave  No alley      Reg  ...       7590         8
# ...       ...    ...       ...      ...  ...        ...       ...
# 2574     8854   Pave  No alley      Reg  ...       7902        93
# 2575    13680   Pave  No alley      IR1  ...      11947        54
# 2576     6270   Pave  No alley      Reg  ...       5269        58
# 2577     8826   Pave  No alley      Reg  ...       7841         7
# 2578     9554   Pave  No alley      IR1  ...       8489        13
#
#      TotalFullBath TotalHalfBath GarageAgeAtSale            Prop_Addr  \
# 0              2.0           0.0            71.0      436 HAYWARD AVE
# 1              3.0           0.0            25.0         3416 WEST ST
# 2              1.0           0.0            77.0         320 S 2ND ST
# 3              1.0           0.0            69.0     1524 DOUGLAS AVE
# 4              3.0           1.0             8.0    2304 FILLMORE AVE
# ...            ...           ...             ...                  ...
# 2574           1.0           0.0            93.0   1021 RIDGEWOOD AVE
# 2575           2.0           0.0            54.0        3619 MARY CIR
# 2576           2.0           0.0            58.0  2140 SUNSET DR 2142
# 2577           3.0           1.0             7.0    5319 CLEMENS BLVD
# 2578           2.0           1.0            13.0      1025 VERMONT CT
#
#                                                MA_Ownr1         MA_Ownr2  \
# 0                               GREINER, RODNEY & CELIA              NaN
# 1                             HUBERT, JOHN F & GRETTA R              NaN
# 2                                          SKLENAR, TIM    CARNEY, SARAH
# 3                                        MILLARD, TAMMY              NaN
# 4                                        SEBBAG, LIONEL  LEVIN, ALISON P
# ...                                                 ...              ...
# 2574                                    KRIER, DANIEL A              NaN
# 2575                              SCHEIBE, KEVIN & MARY              NaN
# 2576  SALTER, BENJAMIN SCOTT & SALTER, TERRILL JOHNSTON              NaN
# 2577                   POLAND, CHRISTOPHER A & ANDREA C              NaN
# 2578                            SCHILTZ, JAMES & BREELY              NaN
#
#        Latitude  Longitude
# 0     42.018564 -93.651619
# 1     42.024855 -93.663671
# 2     42.021548 -93.614068
# 3     42.037391 -93.612207
# 4     42.044554 -93.631818
# ...         ...        ...
# 2574  42.032102 -93.626373
# 2575  42.027669 -93.666138
# 2576  42.020129 -93.643832
# 2577  42.016802 -93.689748
# 2578  42.030997 -93.682220
#
# [2579 rows x 90 columns]

# %%
feature_cols = ['GrLivArea', 'MSSubClass', 'MSZoning',
       'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
       'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
       'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
       'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
       'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
       '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
       'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
       'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'ExteriorSF',
       'AgeAtSale', 'TotalFullBath', 'TotalHalfBath', 'GarageAgeAtSale']

X = df_raw[feature_cols]
y = df_raw['SalePrice']

# %%
def ordinal_encode(df):
    # applies OrdinalEncoder's fit_transform to columns with string dtype
    ordenc = preprocessing.OrdinalEncoder()
    categorical_columns = df.columns[df.dtypes == 'object']
    df.loc[:, categorical_columns] = ordenc.fit_transform(df.loc[:, categorical_columns])
    return df

# %%
X = ordinal_encode(X)
# Out:
# /var/folders/j2/lf9zt3017c3fz8rrnty2f8h80000gn/T/ipykernel_30553/1223862541.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, categorical_columns] = ordenc.fit_transform(df.loc[:, categorical_columns])

# %% [markdown]
# We will first see how a random forest regressor performs on the dataset with  just the minimal feature engineering obtained from preprocessing.

# %%
rf = RandomForestRegressor()

defaultparams = {
    'n_estimators': [100],
}

rf_cv = GridSearchCV(rf, defaultparams)
rf_cv.fit(X, y)
rf_cv.score(X, y)
# Out:
# 0.9841806382386371

# %%
default_rf = rf_cv.best_estimator_
featureimportances = pd.Series(default_rf.feature_importances_, index=X.columns)
featureimportances.nlargest(30).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
residuals = y - default_rf.predict(X)
residuals.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
np.mean(residuals**2)
# Out:
# 89056138.10027108

# %%
np.sqrt(np.mean(residuals**2))
# Out:
# 9436.955976387253

# %% [markdown]
# We already have good R^2, but the feature importances suggest that this is primarily being driven by an indicator of overall quality of the house's material and finish and features tracking square footage. We will try to engineer the features to yield a model that has more insight into how fungible features impact sale price. Our overall approach will be to keep track of the features that we cannot change, but try to discretize them so that the model cannot simply encode the solution into (combinations of) continuous variables.

# %% [markdown]
# ## Feature engineering

# %%
df_new = df_raw.copy()

# %% [markdown]
# #### Target
# 'SalePrice',
#
# For obvious reasons, we will not be touching this.

# %% [markdown]
# #### Building square footage features
# 'GrLivArea',
# '1stFlrSF',
# '2ndFlrSF',
# 'LowQualFinSF',
# 'LotArea',
# 'ExteriorSF',
# 'BsmtFinSF1',
# 'BsmtFinSF2',
# 'BsmtUnfSF',
# 'TotalBsmtSF',

# %%
df_raw.plot.scatter(x='GrLivArea', y='LotArea', ylim = (0, 30000))
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='LotArea'>

# %% [markdown]
# The above-ground living area is not a great guide to lot area.

# %%
df_raw.plot.scatter(x='GrLivArea', y='1stFlrSF')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='1stFlrSF'>

# %%
df_raw.plot.scatter(x='GrLivArea', y='TotalBsmtSF')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='TotalBsmtSF'>

# %% [markdown]
# We will generate TotalSF and keep ExteriorSF since a house's sf is not a good guide to the lot sf. We will toss out the details regarding the makeup of the square footage.

# %%
df_new['TotalSF'] = df_new['GrLivArea'] + df_new['TotalBsmtSF']
df_new['2Stories'] = df_new['2ndFlrSF'] > 0
df_new = df_new.drop(['GrLivArea', '1stFlrSF', '2ndFlrSF', 
                      'LowQualFinSF', 'LotArea', 'BsmtFinSF1', 
                      'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF'], axis=1) # note we keep ExteriorSF

# %% [markdown]
# #### Building quality features
# 'KitchenQual',
# 'OverallQual',
# 'OverallCond',
# 'Functional',
# 'YearBuilt',
# 'AgeAtSale',
# 'YearRemodAdd',

# %%
df_raw.plot.scatter(x='AgeAtSale', y='OverallQual')
# Out:
# <AxesSubplot:xlabel='AgeAtSale', ylabel='OverallQual'>

# %%
df_raw.plot.scatter(x='AgeAtSale', y='OverallCond')
# Out:
# <AxesSubplot:xlabel='AgeAtSale', ylabel='OverallCond'>

# %%
df_raw.boxplot(by='OverallQual', column='SalePrice')
# Out:
# <AxesSubplot:title={'center':'SalePrice'}, xlabel='OverallQual'>

# %%
df_raw.boxplot(by='OverallCond', column='SalePrice', )
# Out:
# <AxesSubplot:title={'center':'SalePrice'}, xlabel='OverallCond'>

# %%
# note that if there has been no remodel, YearRemodAdd is date of original construction
df_new['TimeSinceLastWork'] = df_new['YrSold'] - df_new['YearRemodAdd']
df_new = df_new.drop(['KitchenQual', 'OverallQual', 'OverallCond', 'Functional', 
             'YearBuilt', 'YearRemodAdd'], axis=1)

# %% [markdown]
# #### Room counts features
# 'BsmtFullBath',
# 'BsmtHalfBath',
# 'FullBath',
# 'HalfBath',
# 'BedroomAbvGr',
# 'KitchenAbvGr',
# 'TotRmsAbvGrd',
# 'TotalFullBath',
# 'TotalHalfBath',

# %%
df_new = df_new.drop(['BsmtFullBath', 'BsmtHalfBath', 
                      'FullBath', 'HalfBath', 'KitchenAbvGr', 
                      'TotRmsAbvGrd'], axis=1)
# keep BedroomAbvGr, TotalFullBath, TotalHalfBath

# %% [markdown]
# #### Property features
# 'LotShape',
# 'LandContour',
# 'LotConfig',
# 'LotFrontage',
# 'LandSlope',

# %%
df_new = df_new.drop(['LotShape', 'LandContour', 'LotConfig', 'LotFrontage', 'LandSlope'], axis=1)
# drop all of these

# %% [markdown]
# #### Nearby area and access features
# 'Neighborhood',
# 'MSZoning',
# 'Condition1', (note that this specifies proximity to certain conditions)
# 'Condition2',
# 'Street',
# 'Alley',
# 'PavedDrive',

# %%
df_new = df_new.drop(['MSZoning', 'Neighborhood', 'Condition1', 'Condition2', 'Street', 'Alley', 'PavedDrive'], axis=1)
# drop all

# %% [markdown]
# #### Building type and detail features
# 'BldgType',
# 'HouseStyle',
# 'MSSubClass',

# %%
# df_new['MSSubClass'] = df_new['MSSubClass'].astype('category') # MSSubClass more-or-less includes other features
df_new = df_new.drop(['MSSubClass', 'BldgType', 'HouseStyle'], axis=1)

# %% [markdown]
# #### Building exterior features
# 'RoofStyle',
# 'RoofMatl',
# 'Exterior1st',
# 'Exterior2nd',
# 'MasVnrType',
# 'MasVnrArea',
# 'ExterQual',
# 'ExterCond',

# %%
df_new = df_new.drop(['RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 
                      'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond'], axis=1)

# %% [markdown]
# #### Basement features
# 'Foundation',
# 'BsmtQual',
# 'BsmtCond',
# 'BsmtExposure',
# 'BsmtFinType1',
# 'BsmtFinType2',

# %%
df_new = df_new.drop(['Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'], axis=1)

# %% [markdown]
# #### Garage features
# 'GarageType',
# 'GarageFinish',
# 'GarageCars',
# 'GarageArea',
# 'GarageQual',
# 'GarageCond',
# 'GarageAgeAtSale',

# %%
df_new = df_new.drop(['GarageType', 'GarageFinish', 'GarageArea', 
                      'GarageQual', 'GarageCond', 'GarageAgeAtSale'], axis=1)
# keep GarageCars

# %% [markdown]
# #### Electricity, Climate Control, and Utilities
# 'Heating',
# 'HeatingQC',
# 'CentralAir',
# 'Electrical',
# 'Utilities',

# %%
df_new = df_new.drop(['Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'Utilities'], axis=1)

# %% [markdown]
# #### Fireplaces
# 'Fireplaces',
# 'FireplaceQu',

# %%
df_new['HasFireplace'] = df_new['Fireplaces'] > 1
df_new = df_new.drop(['Fireplaces', 'FireplaceQu'], axis=1)

# %% [markdown]
# #### Porch features
# 'WoodDeckSF',
# 'OpenPorchSF',
# 'EnclosedPorch',
# '3SsnPorch',
# 'ScreenPorch',

# %%
df_new['HasPorch'] = np.sum(df_new[['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']], axis=1) > 0
df_new = df_new.drop(['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch'], axis=1)

# %% [markdown]
# #### Pool features
# 'PoolArea',
# 'PoolQC',

# %%
df_new['HasPool'] = df_new['PoolArea'] > 0
df_new = df_new.drop(['PoolArea', 'PoolQC'], axis=1)

# %% [markdown]
# #### Miscellaneous features
# 'Fence',
# 'MiscFeature',
# 'MiscVal',

# %%
df_new = df_new.drop(['Fence', 'MiscFeature', 'MiscVal'], axis=1)

# %% [markdown]
# #### Sale features
# 'MoSold',
# 'YrSold',
# 'SaleType',
# 'SaleCondition',

# %%
df_new = df_new.loc[df_new['SaleCondition'] == 'Normal']
df_new = df_new.drop(['MoSold', 'YrSold', 'SaleType', 'SaleCondition'], axis=1)

# %% [markdown]
# #### Identifying features (do not use)
# 'PID',
# 'Prop_Addr',
# 'MA_Ownr1',
# 'MA_Ownr2',
# 'Latitude',
# 'Longitude'

# %%
df_new = df_new.drop(['PID', 'Prop_Addr', 'MA_Ownr1', 'MA_Ownr2', 'Latitude', 'Longitude'], axis=1)

# %%
df_new.columns
# Out:
# Index(['SalePrice', 'BedroomAbvGr', 'GarageCars', 'ExteriorSF', 'AgeAtSale',
#        'TotalFullBath', 'TotalHalfBath', 'TotalSF', '2Stories',
#        'TimeSinceLastWork', 'HasFireplace', 'HasPorch', 'HasPool'],
#       dtype='object')

# %% [markdown]
# ## Random Forest Regression on New Features

# %%
df_new.columns
# Out:
# Index(['SalePrice', 'BedroomAbvGr', 'GarageCars', 'ExteriorSF', 'AgeAtSale',
#        'TotalFullBath', 'TotalHalfBath', 'TotalSF', '2Stories',
#        'TimeSinceLastWork', 'HasFireplace', 'HasPorch', 'HasPool'],
#       dtype='object')

# %%
X_new = ordinal_encode(df_new.drop('SalePrice', axis=1))
y_new = df_new['SalePrice']

# %%
X_new.dtypes
# Out:
# BedroomAbvGr           int64
# GarageCars           float64
# ExteriorSF             int64
# AgeAtSale              int64
# TotalFullBath        float64
# TotalHalfBath        float64
# TotalSF              float64
# 2Stories                bool
# TimeSinceLastWork      int64
# HasFireplace            bool
# HasPorch                bool
# HasPool                 bool
# dtype: object

# %%
rf = RandomForestRegressor()

paramgrid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'min_samples_leaf': [1, 3, 5],
    'max_depth': [20, 30, 40, 50]
}

rf_cv = GridSearchCV(rf, paramgrid, cv=10)
rf_cv.fit(X_new, y_new)
rf_cv.score(X_new, y_new)
# Out:
# 0.9833307723222544

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 400}

# %%
best_rf = rf_cv.best_estimator_
featureimportances = pd.Series(best_rf.feature_importances_, index=X_new.columns)
featureimportances.nlargest(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
residuals = y_new - best_rf.predict(X_new)
residuals.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
np.mean(residuals**2)
# Out:
# 83946526.71364427

# %%
np.sqrt(np.mean(residuals**2))
# Out:
# 9162.233718566902

# %%
df_expanded = df_new.copy()

# %%
# new features from group meeting
df_expanded['Neighborhood'] = df_raw['Neighborhood']
df_expanded['RoofMatl'] = df_raw['RoofMatl']
df_expanded['KitchenQual'] = df_raw['KitchenQual']
df_expanded['FinBasmt'] = (df_raw.TotalBsmtSF - df_raw.BsmtUnfSF) > 0 

df_expanded['Bathrooms'] = df_raw['TotalFullBath'] + (df_raw['TotalHalfBath'] / 2) + df_raw['BsmtFullBath'] + (df_raw['BsmtHalfBath'] / 2)
df_expanded = df_expanded.drop(['TotalFullBath', 'TotalHalfBath'], axis=1)

# %%
df_expanded.columns
# Out:
# Index(['SalePrice', 'BedroomAbvGr', 'GarageCars', 'ExteriorSF', 'AgeAtSale',
#        'TotalSF', '2Stories', 'TimeSinceLastWork', 'HasFireplace', 'HasPorch',
#        'HasPool', 'Neighborhood', 'RoofMatl', 'KitchenQual', 'FinBasmt',
#        'Bathrooms'],
#       dtype='object')

# %%
df_expanded
# Out:
#       SalePrice  BedroomAbvGr  GarageCars  ExteriorSF  AgeAtSale  TotalSF  \
# 0        126000             2         2.0        7034         71   1712.0
# 1        139500             2         1.0        3186         25   2098.0
# 2        124900             2         1.0        5059         77   1838.0
# 3        114000             2         1.0        7429        109   1444.0
# 4        227000             3         2.0        7590          8   2475.0
# ...         ...           ...         ...         ...        ...      ...
# 2574     121000             2         1.0        7902         93   1904.0
# 2575     139600             4         2.0       11947         54   1733.0
# 2576     145000             4         3.0        5269         58   3003.0
# 2577     217500             3         2.0        7841          7   2827.0
# 2578     215000             3         2.0        8489         13   2688.0
#
#       2Stories  TimeSinceLastWork  HasFireplace  HasPorch  HasPool  \
# 0        False                 60         False      True    False
# 1        False                 25         False      True    False
# 2        False                  0         False      True    False
# 3         True                  6         False      True    False
# 4         True                  8         False      True    False
# ...        ...                ...           ...       ...      ...
# 2574     False                 59         False      True    False
# 2575     False                 54         False     False    False
# 2576      True                 57         False     False    False
# 2577      True                  7         False      True    False
# 2578      True                 12         False      True    False
#
#      Neighborhood RoofMatl KitchenQual  FinBasmt  Bathrooms
# 0           SWISU  CompShg          TA      True        3.0
# 1         Edwards  CompShg          Gd      True        4.0
# 2          IDOTRR  CompShg          Gd      True        1.0
# 3         OldTown  CompShg          TA     False        1.0
# 4          NWAmes  CompShg          Gd      True        4.5
# ...           ...      ...         ...       ...        ...
# 2574      BrkSide  CompShg          Fa     False        1.0
# 2575      Edwards  CompShg          TA     False        2.0
# 2576      Crawfor  CompShg          TA      True        2.0
# 2577      CollgCr  CompShg          Gd      True        4.5
# 2578      SawyerW  CompShg          Gd      True        2.5
#
# [2413 rows x 16 columns]

# %%
X_expanded = ordinal_encode(df_expanded.drop('SalePrice', axis=1))
y_expanded = df_expanded['SalePrice']

# %%
rf_cv.fit(X_expanded, y_expanded)
rf_cv.score(X_expanded, y_expanded)
# Out:
# 0.9856693998277506

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 500}

# %%
best_rf = rf_cv.best_estimator_
featureimportances = pd.Series(best_rf.feature_importances_, index=X_expanded.columns)
featureimportances.nlargest(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
residuals = y_expanded - best_rf.predict(X_expanded)
residuals.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
np.mean(residuals**2)
# Out:
# 72169157.05029172

# %%
np.sqrt(np.mean(residuals**2))
# Out:
# 8495.24320136226

# %%
import shap
explainer = shap.TreeExplainer(best_rf)

# %%
shap_values = explainer.shap_values(X_expanded)

# %%
shap.summary_plot(shap_values, X_expanded)

# %%
shap.dependence_plot('KitchenQual', shap_values, X_expanded)

# %%
shap.dependence_plot('KitchenQual', shap_values, X_expanded, interaction_index="AgeAtSale")

# %%
shap.dependence_plot('KitchenQual', shap_values, X_expanded, interaction_index="Neighborhood")

# %%
shap.dependence_plot('AgeAtSale', shap_values, X_expanded, interaction_index='KitchenQual')

# %% [markdown]
# ### Random feature subset experiments

# %%
features =
